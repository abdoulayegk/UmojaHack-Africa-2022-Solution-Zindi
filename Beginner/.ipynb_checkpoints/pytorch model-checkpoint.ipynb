# %%
import random
import warnings

import matplotlib.pyplot as plt
import missingno as mn
import numpy as np
import pandas as pd
import seaborn as sns
from autoxgb import AutoXGB
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
from sklearn.ensemble import HistGradientBoostingClassifier, RandomForestClassifier
from sklearn.impute import SimpleImputer
from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from xgboost import XGBClassifier

random_state= 42
np.random.seed(random_state)
random.seed(random_state)
warnings.filterwarnings('ignore')
# Out:
# /home/balde/Downloads/AUR/y/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
ss = pd.read_csv('SampleSubmission.csv')

# %%
train.head()
# Out:
#                 ID             Datetime  Sensor1_PM2.5  Sensor2_PM2.5  \
# 0  ID_QF0ZTQJ2SF5Q  2021-11-03 04:06:31          52.58          49.52
# 1  ID_4GTK689CNX5S  2021-11-08 18:43:23          35.25          33.40
# 2  ID_DL7VVKW9U7XQ  2021-11-07 09:50:33          19.18          23.50
# 3  ID_6XQOMBXM2DG3  2022-01-01 18:55:15          19.40          15.48
# 4  ID_UQZW9ISJY9QE  2021-11-05 22:23:48          38.30          34.77
#
#    Temperature  Relative_Humidity  Offset_fault
# 0         17.4               96.0             0
# 1         25.0               75.0             0
# 2         24.9               75.0             0
# 3         24.9               70.0             0
# 4         20.9               89.0             0

# %%
test.head()
# Out:
#                 ID             Datetime  Sensor1_PM2.5  Sensor2_PM2.5  \
# 0  ID_STL3V9B2OU12  2022-01-28 08:49:41          90.75         114.78
# 1  ID_U2EKAY4SGA94  2022-02-16 21:30:17          56.03          52.18
# 2  ID_UJFLEWQR0U4N  2022-01-24 17:57:18         387.35         346.73
# 3  ID_S2C2GPGA4R5I  2022-01-31 07:07:09          63.17          83.85
# 4  ID_5V2C2ZL221H8  2022-01-31 00:37:05          69.23          53.07
#
#    Temperature  Relative_Humidity
# 0         22.2               56.0
# 1          NaN                NaN
# 2         28.1               63.0
# 3         21.6               82.0
# 4         22.7               80.0

# %%
ss.head()
# Out:
#                 ID  Offset_fault
# 0  ID_STL3V9B2OU12             0
# 1  ID_U2EKAY4SGA94             0
# 2  ID_UJFLEWQR0U4N             0
# 3  ID_S2C2GPGA4R5I             0
# 4  ID_5V2C2ZL221H8             0

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 297177 entries, 0 to 297176
# Data columns (total 7 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   ID                 297177 non-null  object
#  1   Datetime           297177 non-null  object
#  2   Sensor1_PM2.5      293563 non-null  float64
#  3   Sensor2_PM2.5      293563 non-null  float64
#  4   Temperature        293628 non-null  float64
#  5   Relative_Humidity  293628 non-null  float64
#  6   Offset_fault       297177 non-null  int64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 15.9+ MB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127361 entries, 0 to 127360
# Data columns (total 6 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   ID                 127361 non-null  object
#  1   Datetime           127361 non-null  object
#  2   Sensor1_PM2.5      127361 non-null  float64
#  3   Sensor2_PM2.5      127361 non-null  float64
#  4   Temperature        39271 non-null   float64
#  5   Relative_Humidity  39271 non-null   float64
# dtypes: float64(4), object(2)
# memory usage: 5.8+ MB

# %%
mn.matrix(train)
# Out:
# <AxesSubplot:>

# %%
train = train.drop('ID',axis=1)
test = test.drop('ID',axis=1)

# %%
train.loc[:, 'Sensor1_PM2.5':'Offset_fault'].describe().T.style.bar(subset=['mean'], color='#206ff2')\
                            .background_gradient(subset=['std'], cmap='Reds')\
                            .background_gradient(subset=['50%'], cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_54122_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #206ff2 51.8%, transparent 51.8%);
# }
# #T_54122_row0_col2 {
#   background-color: #69000d;
#   color: #f1f1f1;
# }
# #T_54122_row0_col5 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_54122_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #206ff2 48.5%, transparent 48.5%);
# }
# #T_54122_row1_col2 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_54122_row1_col5 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_54122_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #206ff2 29.6%, transparent 29.6%);
# }
# #T_54122_row2_col2 {
#   background-color: #fee1d4;
#   color: #000000;
# }
# #T_54122_row2_col5 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_54122_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #206ff2 100.0%, transparent 100.0%);
# }
# #T_54122_row3_col2 {
#   background-color: #fa6849;
#   color: #f1f1f1;
# }
# #T_54122_row3_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_54122_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #206ff2 0.5%, transparent 0.5%);
# }
# #T_54122_row4_col2 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_54122_row4_col5 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_54122">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_54122_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_54122_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_54122_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_54122_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_54122_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_54122_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_54122_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_54122_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_54122_level0_row0" class="row_heading level0 row0" >Sensor1_PM2.5</th>
#       <td id="T_54122_row0_col0" class="data row0 col0" >293563.000000</td>
#       <td id="T_54122_row0_col1" class="data row0 col1" >40.751195</td>
#       <td id="T_54122_row0_col2" class="data row0 col2" >28.526182</td>
#       <td id="T_54122_row0_col3" class="data row0 col3" >-9.450000</td>
#       <td id="T_54122_row0_col4" class="data row0 col4" >22.430000</td>
#       <td id="T_54122_row0_col5" class="data row0 col5" >36.470000</td>
#       <td id="T_54122_row0_col6" class="data row0 col6" >49.420000</td>
#       <td id="T_54122_row0_col7" class="data row0 col7" >997.960000</td>
#     </tr>
#     <tr>
#       <th id="T_54122_level0_row1" class="row_heading level0 row1" >Sensor2_PM2.5</th>
#       <td id="T_54122_row1_col0" class="data row1 col0" >293563.000000</td>
#       <td id="T_54122_row1_col1" class="data row1 col1" >38.183018</td>
#       <td id="T_54122_row1_col2" class="data row1 col2" >28.647761</td>
#       <td id="T_54122_row1_col3" class="data row1 col3" >-9.700000</td>
#       <td id="T_54122_row1_col4" class="data row1 col4" >19.520000</td>
#       <td id="T_54122_row1_col5" class="data row1 col5" >33.720000</td>
#       <td id="T_54122_row1_col6" class="data row1 col6" >47.570000</td>
#       <td id="T_54122_row1_col7" class="data row1 col7" >997.260000</td>
#     </tr>
#     <tr>
#       <th id="T_54122_level0_row2" class="row_heading level0 row2" >Temperature</th>
#       <td id="T_54122_row2_col0" class="data row2 col0" >293628.000000</td>
#       <td id="T_54122_row2_col1" class="data row2 col1" >23.316554</td>
#       <td id="T_54122_row2_col2" class="data row2 col2" >3.836971</td>
#       <td id="T_54122_row2_col3" class="data row2 col3" >16.700000</td>
#       <td id="T_54122_row2_col4" class="data row2 col4" >20.400000</td>
#       <td id="T_54122_row2_col5" class="data row2 col5" >21.900000</td>
#       <td id="T_54122_row2_col6" class="data row2 col6" >26.300000</td>
#       <td id="T_54122_row2_col7" class="data row2 col7" >34.900000</td>
#     </tr>
#     <tr>
#       <th id="T_54122_level0_row3" class="row_heading level0 row3" >Relative_Humidity</th>
#       <td id="T_54122_row3_col0" class="data row3 col0" >293628.000000</td>
#       <td id="T_54122_row3_col1" class="data row3 col1" >78.653623</td>
#       <td id="T_54122_row3_col2" class="data row3 col2" >14.772725</td>
#       <td id="T_54122_row3_col3" class="data row3 col3" >27.000000</td>
#       <td id="T_54122_row3_col4" class="data row3 col4" >68.000000</td>
#       <td id="T_54122_row3_col5" class="data row3 col5" >84.000000</td>
#       <td id="T_54122_row3_col6" class="data row3 col6" >91.000000</td>
#       <td id="T_54122_row3_col7" class="data row3 col7" >99.000000</td>
#     </tr>
#     <tr>
#       <th id="T_54122_level0_row4" class="row_heading level0 row4" >Offset_fault</th>
#       <td id="T_54122_row4_col0" class="data row4 col0" >297177.000000</td>
#       <td id="T_54122_row4_col1" class="data row4 col1" >0.371072</td>
#       <td id="T_54122_row4_col2" class="data row4 col2" >0.483092</td>
#       <td id="T_54122_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_54122_row4_col4" class="data row4 col4" >0.000000</td>
#       <td id="T_54122_row4_col5" class="data row4 col5" >0.000000</td>
#       <td id="T_54122_row4_col6" class="data row4 col6" >1.000000</td>
#       <td id="T_54122_row4_col7" class="data row4 col7" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
### Now let's visualize 
sns.countplot(train.Offset_fault)
# Out:
# <AxesSubplot:xlabel='Offset_fault', ylabel='count'>

# %%
# Extract day, month year and hour from the Datetime column
# day
def converte_dates(df):
    
    df['Datetime'] = pd.to_datetime(df['Datetime'])
    
    #
    df['Datetime_day'] = df.Datetime.dt.day

    # month
    df['Datetime_month'] = df.Datetime.dt.month

    # year
    df['Datetime_year'] = df.Datetime.dt.year

    # hour
    df['Datetime_hour'] = df.Datetime.dt.hour
    
    # minute
    df['Datetime_minute'] = df.Datetime.dt.minute
    
    # day of week
    df['Datetime_dayofweek'] = df.Datetime.dt.weekday
    
    
    return df


train = converte_dates(train)
test = converte_dates(test)

# %%
def more_features(df):
    df['is_morning'] = (6 <= df['Datetime_hour']) & (df['Datetime_hour'] < 12)#.median()
    df['is_afternoon'] = (12 <= df['Datetime_hour']) & (df['Datetime_hour'] < 18)#.median()
    df['is_evening'] = (18 <= df['Datetime_hour']) & (df['Datetime_hour'] <= 23)#.median()
    df['is_night'] = (0 <= df['Datetime_hour']) & (df['Datetime_hour'] < 6)#.median()
    return df


train = more_features(train)
test = more_features(test)

# %%
corr = train.corr()
corr.style.background_gradient()
# Out:
# <style type="text/css">
# #T_36e2e_row0_col0, #T_36e2e_row1_col1, #T_36e2e_row2_col2, #T_36e2e_row3_col3, #T_36e2e_row4_col4, #T_36e2e_row5_col5, #T_36e2e_row6_col6, #T_36e2e_row7_col7, #T_36e2e_row8_col8, #T_36e2e_row9_col9, #T_36e2e_row10_col10, #T_36e2e_row11_col11, #T_36e2e_row12_col12, #T_36e2e_row13_col13, #T_36e2e_row14_col14 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_36e2e_row0_col1, #T_36e2e_row1_col0 {
#   background-color: #023f64;
#   color: #f1f1f1;
# }
# #T_36e2e_row0_col2, #T_36e2e_row3_col5, #T_36e2e_row8_col3, #T_36e2e_row9_col0 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_36e2e_row0_col3 {
#   background-color: #2786bb;
#   color: #f1f1f1;
# }
# #T_36e2e_row0_col4 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_36e2e_row0_col5, #T_36e2e_row0_col12 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_36e2e_row0_col6 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_36e2e_row0_col7 {
#   background-color: #4c99c5;
#   color: #f1f1f1;
# }
# #T_36e2e_row0_col8, #T_36e2e_row5_col12, #T_36e2e_row6_col12, #T_36e2e_row7_col0, #T_36e2e_row9_col12, #T_36e2e_row13_col0 {
#   background-color: #9ebad9;
#   color: #000000;
# }
# #T_36e2e_row0_col9, #T_36e2e_row1_col4, #T_36e2e_row1_col9, #T_36e2e_row2_col0, #T_36e2e_row2_col1, #T_36e2e_row2_col3, #T_36e2e_row2_col9, #T_36e2e_row3_col2, #T_36e2e_row3_col9, #T_36e2e_row3_col12, #T_36e2e_row4_col9, #T_36e2e_row5_col9, #T_36e2e_row6_col7, #T_36e2e_row6_col9, #T_36e2e_row7_col5, #T_36e2e_row7_col6, #T_36e2e_row7_col9, #T_36e2e_row7_col10, #T_36e2e_row8_col9, #T_36e2e_row8_col14, #T_36e2e_row10_col9, #T_36e2e_row11_col9, #T_36e2e_row12_col9, #T_36e2e_row13_col9, #T_36e2e_row14_col8, #T_36e2e_row14_col9, #T_36e2e_row14_col11, #T_36e2e_row14_col13 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_36e2e_row0_col10, #T_36e2e_row12_col1, #T_36e2e_row12_col10 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_36e2e_row0_col11, #T_36e2e_row1_col11 {
#   background-color: #bbc7e0;
#   color: #000000;
# }
# #T_36e2e_row0_col13 {
#   background-color: #a8bedc;
#   color: #000000;
# }
# #T_36e2e_row0_col14, #T_36e2e_row4_col2, #T_36e2e_row10_col3, #T_36e2e_row10_col7 {
#   background-color: #79abd0;
#   color: #f1f1f1;
# }
# #T_36e2e_row1_col2 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_36e2e_row1_col3 {
#   background-color: #2d8abd;
#   color: #f1f1f1;
# }
# #T_36e2e_row1_col5, #T_36e2e_row2_col13, #T_36e2e_row14_col12 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_36e2e_row1_col6 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_36e2e_row1_col7 {
#   background-color: #4a98c5;
#   color: #f1f1f1;
# }
# #T_36e2e_row1_col8, #T_36e2e_row4_col12, #T_36e2e_row7_col12, #T_36e2e_row10_col12, #T_36e2e_row11_col2 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_36e2e_row1_col10, #T_36e2e_row2_col10, #T_36e2e_row8_col10, #T_36e2e_row9_col10, #T_36e2e_row11_col10 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_36e2e_row1_col12, #T_36e2e_row3_col8 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_36e2e_row1_col13 {
#   background-color: #abbfdc;
#   color: #000000;
# }
# #T_36e2e_row1_col14, #T_36e2e_row2_col7, #T_36e2e_row9_col2, #T_36e2e_row9_col3, #T_36e2e_row10_col2 {
#   background-color: #7bacd1;
#   color: #f1f1f1;
# }
# #T_36e2e_row2_col4, #T_36e2e_row4_col5, #T_36e2e_row5_col4, #T_36e2e_row6_col4, #T_36e2e_row8_col0, #T_36e2e_row8_col4, #T_36e2e_row9_col5, #T_36e2e_row12_col4, #T_36e2e_row13_col4, #T_36e2e_row13_col5, #T_36e2e_row14_col5 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_36e2e_row2_col5, #T_36e2e_row8_col1 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_36e2e_row2_col6 {
#   background-color: #6da6cd;
#   color: #f1f1f1;
# }
# #T_36e2e_row2_col8 {
#   background-color: #2f8bbe;
#   color: #f1f1f1;
# }
# #T_36e2e_row2_col11 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_36e2e_row2_col12, #T_36e2e_row8_col13 {
#   background-color: #04649e;
#   color: #f1f1f1;
# }
# #T_36e2e_row2_col14 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_36e2e_row3_col0, #T_36e2e_row6_col3 {
#   background-color: #65a3cb;
#   color: #f1f1f1;
# }
# #T_36e2e_row3_col1, #T_36e2e_row6_col2, #T_36e2e_row13_col6 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_36e2e_row3_col4, #T_36e2e_row5_col0, #T_36e2e_row7_col4, #T_36e2e_row14_col4 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_36e2e_row3_col6 {
#   background-color: #60a1ca;
#   color: #f1f1f1;
# }
# #T_36e2e_row3_col7 {
#   background-color: #88b1d4;
#   color: #000000;
# }
# #T_36e2e_row3_col10, #T_36e2e_row12_col0 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_36e2e_row3_col11 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_36e2e_row3_col13, #T_36e2e_row9_col1, #T_36e2e_row10_col1, #T_36e2e_row10_col5 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_36e2e_row3_col14 {
#   background-color: #2383ba;
#   color: #f1f1f1;
# }
# #T_36e2e_row4_col0 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_36e2e_row4_col1, #T_36e2e_row6_col10 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_36e2e_row4_col3 {
#   background-color: #7dacd1;
#   color: #f1f1f1;
# }
# #T_36e2e_row4_col6, #T_36e2e_row8_col6, #T_36e2e_row9_col6, #T_36e2e_row9_col7, #T_36e2e_row11_col7, #T_36e2e_row12_col7, #T_36e2e_row14_col7 {
#   background-color: #75a9cf;
#   color: #f1f1f1;
# }
# #T_36e2e_row4_col7, #T_36e2e_row8_col7, #T_36e2e_row11_col6, #T_36e2e_row12_col6, #T_36e2e_row13_col3, #T_36e2e_row14_col6 {
#   background-color: #76aad0;
#   color: #f1f1f1;
# }
# #T_36e2e_row4_col8, #T_36e2e_row5_col14, #T_36e2e_row6_col8, #T_36e2e_row7_col14, #T_36e2e_row9_col8, #T_36e2e_row9_col14, #T_36e2e_row10_col8 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_36e2e_row4_col10, #T_36e2e_row13_col10 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_36e2e_row4_col11, #T_36e2e_row5_col11, #T_36e2e_row5_col13, #T_36e2e_row6_col11, #T_36e2e_row9_col11, #T_36e2e_row9_col13, #T_36e2e_row10_col13, #T_36e2e_row14_col2 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_36e2e_row4_col13, #T_36e2e_row7_col11, #T_36e2e_row10_col11 {
#   background-color: #ced0e6;
#   color: #000000;
# }
# #T_36e2e_row4_col14, #T_36e2e_row5_col8, #T_36e2e_row6_col14, #T_36e2e_row10_col14 {
#   background-color: #91b5d6;
#   color: #000000;
# }
# #T_36e2e_row5_col1 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_36e2e_row5_col2 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
# }
# #T_36e2e_row5_col3 {
#   background-color: #6fa7ce;
#   color: #f1f1f1;
# }
# #T_36e2e_row5_col6 {
#   background-color: #348ebf;
#   color: #f1f1f1;
# }
# #T_36e2e_row5_col7 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_36e2e_row5_col10 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_36e2e_row6_col0 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_36e2e_row6_col1 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_36e2e_row6_col5, #T_36e2e_row13_col2 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_36e2e_row6_col13 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_36e2e_row7_col1 {
#   background-color: #9fbad9;
#   color: #000000;
# }
# #T_36e2e_row7_col2 {
#   background-color: #81aed2;
#   color: #f1f1f1;
# }
# #T_36e2e_row7_col3 {
#   background-color: #8eb3d5;
#   color: #000000;
# }
# #T_36e2e_row7_col8 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_36e2e_row7_col13 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_36e2e_row8_col2 {
#   background-color: #2182b9;
#   color: #f1f1f1;
# }
# #T_36e2e_row8_col5, #T_36e2e_row9_col4, #T_36e2e_row10_col4, #T_36e2e_row11_col4, #T_36e2e_row11_col5, #T_36e2e_row11_col14, #T_36e2e_row12_col5, #T_36e2e_row12_col14, #T_36e2e_row13_col14 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_36e2e_row8_col11 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_36e2e_row8_col12 {
#   background-color: #5a9ec9;
#   color: #f1f1f1;
# }
# #T_36e2e_row10_col0 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_36e2e_row10_col6 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
# }
# #T_36e2e_row11_col0 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_36e2e_row11_col1 {
#   background-color: #b7c5df;
#   color: #000000;
# }
# #T_36e2e_row11_col3 {
#   background-color: #4897c4;
#   color: #

# %%
train.head()
# Out:
#              Datetime  Sensor1_PM2.5  Sensor2_PM2.5  Temperature  \
# 0 2021-11-03 04:06:31          52.58          49.52         17.4
# 1 2021-11-08 18:43:23          35.25          33.40         25.0
# 2 2021-11-07 09:50:33          19.18          23.50         24.9
# 3 2022-01-01 18:55:15          19.40          15.48         24.9
# 4 2021-11-05 22:23:48          38.30          34.77         20.9
#
#    Relative_Humidity  Offset_fault  Datetime_day  Datetime_month  \
# 0               96.0             0             3              11
# 1               75.0             0             8              11
# 2               75.0             0             7              11
# 3               70.0             0             1               1
# 4               89.0             0             5              11
#
#    Datetime_year  Datetime_hour  Datetime_minute  Datetime_dayofweek  \
# 0           2021              4                6                   2
# 1           2021             18               43                   0
# 2           2021              9               50                   6
# 3           2022             18               55                   5
# 4           2021             22               23                   4
#
#    is_morning  is_afternoon  is_evening  is_night
# 0       False         False       False      True
# 1       False         False        True     False
# 2        True         False       False     False
# 3       False         False        True     False
# 4       False         False        True     False

# %%
train.shape,test.shape
# Out:
# ((297177, 16), (127361, 15))

# %%
test.head()
# Out:
#              Datetime  Sensor1_PM2.5  Sensor2_PM2.5  Temperature  \
# 0 2022-01-28 08:49:41          90.75         114.78         22.2
# 1 2022-02-16 21:30:17          56.03          52.18          NaN
# 2 2022-01-24 17:57:18         387.35         346.73         28.1
# 3 2022-01-31 07:07:09          63.17          83.85         21.6
# 4 2022-01-31 00:37:05          69.23          53.07         22.7
#
#    Relative_Humidity  Datetime_day  Datetime_month  Datetime_year  \
# 0               56.0            28               1           2022
# 1                NaN            16               2           2022
# 2               63.0            24               1           2022
# 3               82.0            31               1           2022
# 4               80.0            31               1           2022
#
#    Datetime_hour  Datetime_minute  Datetime_dayofweek  is_morning  \
# 0              8               49                   4        True
# 1             21               30                   2       False
# 2             17               57                   0       False
# 3              7                7                   0        True
# 4              0               37                   0       False
#
#    is_afternoon  is_evening  is_night
# 0         False       False     False
# 1         False        True     False
# 2          True       False     False
# 3         False       False     False
# 4         False       False      True

# %%
train = train.drop('Datetime',axis=1)
test = test.drop('Datetime',axis=1)

# %%
train.head()
# Out:
#    Sensor1_PM2.5  Sensor2_PM2.5  Temperature  Relative_Humidity  Offset_fault  \
# 0          52.58          49.52         17.4               96.0             0
# 1          35.25          33.40         25.0               75.0             0
# 2          19.18          23.50         24.9               75.0             0
# 3          19.40          15.48         24.9               70.0             0
# 4          38.30          34.77         20.9               89.0             0
#
#    Datetime_day  Datetime_month  Datetime_year  Datetime_hour  \
# 0             3              11           2021              4
# 1             8              11           2021             18
# 2             7              11           2021              9
# 3             1               1           2022             18
# 4             5              11           2021             22
#
#    Datetime_minute  Datetime_dayofweek  is_morning  is_afternoon  is_evening  \
# 0                6                   2       False         False       False
# 1               43                   0       False         False        True
# 2               50                   6        True         False       False
# 3               55                   5       False         False        True
# 4               23                   4       False         False        True
#
#    is_night
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False

# %%
X = train.drop('Offset_fault',axis=1)
y = train['Offset_fault']

X_test = test.copy

# %% [markdown]
# Here I am capturing NaN per row and making new feature

# %%
def feature_engineering(df):
    df['NaN_row'] = df.isna().sum(axis=1)
    df['std'] = df.std(axis=1)
    return df

X = feature_engineering(X)
test = feature_engineering(test)

# %% [markdown]
# # added code

# %%
def feature_engineering(df):
    df['AverageTemperature'] = df['Temperature'].mean(axis=0)
    df['Relative_Humidity'] = df['Relative_Humidity'].mean(axis=0)
    df['Total_sensor'] = df['Sensor1_PM2.5'] + df['Sensor2_PM2.5']
    return df

X = feature_engineering(X)
test = feature_engineering(test)

X.head()
# Out:
#    Sensor1_PM2.5  Sensor2_PM2.5  Temperature  Relative_Humidity  Datetime_day  \
# 0          52.58          49.52         17.4          78.653623             3
# 1          35.25          33.40         25.0          78.653623             8
# 2          19.18          23.50         24.9          78.653623             7
# 3          19.40          15.48         24.9          78.653623             1
# 4          38.30          34.77         20.9          78.653623             5
#
#    Datetime_month  Datetime_year  Datetime_hour  Datetime_minute  \
# 0              11           2021              4                6
# 1              11           2021             18               43
# 2              11           2021              9               50
# 3               1           2022             18               55
# 4              11           2021             22               23
#
#    Datetime_dayofweek  is_morning  is_afternoon  is_evening  is_night  \
# 0                   2       False         False       False      True
# 1                   0       False         False        True     False
# 2                   6        True         False       False     False
# 3                   5       False         False        True     False
# 4                   4       False         False        True     False
#
#    NaN_row         std  AverageTemperature  Total_sensor
# 0        0  518.087244           23.316554        102.10
# 1        0  517.665411           23.316554         68.65
# 2        0  518.074715           23.316554         42.68
# 3        0  518.627532           23.316554         34.88
# 4        0  517.765326           23.316554         73.07

# %%
pipeline = Pipeline([
    ('impute', SimpleImputer(strategy='mean')),
    ('scale', StandardScaler())
])

X = pd.DataFrame(columns=X.columns, data=pipeline.fit_transform(X))
test = pd.DataFrame(columns=test.columns, data=pipeline.transform(test))

# %%
X.head()
# Out:
#    Sensor1_PM2.5  Sensor2_PM2.5  Temperature  Relative_Humidity  Datetime_day  \
# 0       0.417210       0.398166    -1.551279       5.684342e-14     -1.499409
# 1      -0.194031      -0.167984     0.441388       5.684342e-14     -0.922426
# 2      -0.760831      -0.515682     0.415169       5.684342e-14     -1.037823
# 3      -0.753072      -0.797353     0.415169       5.684342e-14     -1.730202
# 4      -0.086455      -0.119869    -0.633603       5.684342e-14     -1.268616
#
#    Datetime_month  Datetime_year  Datetime_hour  Datetime_minute  \
# 0        0.460813      -0.512278      -1.064973        -1.356771
# 1        0.460813      -0.512278       0.951293         0.780438
# 2        0.460813      -0.512278      -0.344878         1.184775
# 3       -1.926572       1.952065       0.951293         1.473587
# 4        0.460813      -0.512278       1.527369        -0.374810
#
#    Datetime_dayofweek  is_morning  is_afternoon  is_evening  is_night  \
# 0           -0.494456   -0.577240     -0.572272   -0.572018  1.701051
# 1           -1.493974   -0.577240     -0.572272    1.748197 -0.587872
# 2            1.504579    1.732381     -0.572272   -0.572018 -0.587872
# 3            1.004820   -0.577240     -0.572272    1.748197 -0.587872
# 4            0.505061   -0.577240     -0.572272    1.748197 -0.587872
#
#     NaN_row       std  AverageTemperature  Total_sensor
# 0 -0.157159 -0.116191       -1.421085e-14      0.411885
# 1 -0.157159 -0.184993       -1.421085e-14     -0.182852
# 2 -0.157159 -0.118234       -1.421085e-14     -0.644596
# 3 -0.157159 -0.028069       -1.421085e-14     -0.783279
# 4 -0.157159 -0.168696       -1.421085e-14     -0.104265

# %%
test.head()
# Out:
#    Sensor1_PM2.5  Sensor2_PM2.5   Temperature  Relative_Humidity  \
# 0       1.763493       2.690163 -2.927525e-01          -6.437789
# 1       0.538894       0.491588 -9.314965e-16          -6.437789
# 2      12.224781      10.836481  1.254186e+00          -6.437789
# 3       0.790727       1.603870 -4.500683e-01          -6.437789
# 4       1.004467       0.522846 -1.616560e-01          -6.437789
#
#    Datetime_day  Datetime_month  Datetime_year  Datetime_hour  \
# 0      1.385504       -1.926572       1.952065      -0.488897
# 1      0.000746       -1.687833       1.952065       1.383350
# 2      0.923918       -1.926572       1.952065       0.807274
# 3      1.731694       -1.926572       1.952065      -0.632916
# 4      1.731694       -1.926572       1.952065      -1.641050
#
#    Datetime_minute  Datetime_dayofweek  is_morning  is_afternoon  is_evening  \
# 0         1.127013            0.505061    1.732381     -0.572272   -0.572018
# 1         0.029527           -0.494456   -0.577240     -0.572272    1.748197
# 2         1.589112           -1.493974   -0.577240      1.747422   -0.572018
# 3        -1.299009           -1.493974    1.732381     -0.572272   -0.572018
# 4         0.433864           -1.493974   -0.577240     -0.572272   -0.572018
#
#    is_night   NaN_row       std  AverageTemperature  Total_sensor
# 0 -0.587872 -0.157159 -0.386081            0.367284      2.250860
# 1 -0.587872  6.363001  6.221225            0.367284      0.520520
# 2 -0.587872 -0.157159  0.228962            0.367284     11.648424
# 3 -0.587872 -0.157159 -0.214671            0.367284      1.210558
# 4  1.701051 -0.157159 -0.232756            0.367284      0.771039

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=42, test_size=0.01)

# %% [markdown]
# # using XGBoost

# %%
xgb = XGBClassifier()
xgb.fit(X_train,y_train)
pred_x = xgb.predict(X_test)

accuracy_score(y_test, pred_x)
# Out:
# [22:36:05] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# 0.9586137281292059

# %%
pred_xgb = xgb.predict(test)

sub = pd.DataFrame({'ID':ss.ID,'Offset_fault':pred_xgb})
sub.to_csv('xgb.csv',index=False)

# %%
# # lgb_params = {
#     "objective" : "binary",
#     # 'n_estimators':500,
#     "metric" : "accuracy",
#     "boosting": 'gbdt',
#     # #"max_depth" : -1,
#     # "num_leaves" : 13,
#     # "learning_rate" : 0.01,
#     # "bagging_freq": 5,
#     # "bagging_fraction" : 0.4,
#     # "feature_fraction" : 0.05,
#     # "min_data_in_leaf": 80,
#     # "min_sum_heassian_in_leaf": 10,
#     # "tree_learner": "serial",
#     # "boost_from_average": "false",
#     #"lambda_l1" : 5,
#     #"lambda_l2" : 5,
#     "bagging_seed" : random_state,
#     "verbosity" : 1,
#     "seed": random_state
# }


lgb = LGBMClassifier(objective='binary',learning_rate=0.1)
                    
lgb.fit(X_train,y_train)
# Out:
# LGBMClassifier(objective='binary')

# %%
y_pred = lgb.predict(X_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9427994616419919

# %%
print(f"Training Accuracy: {lgb.score(X_train, y_train):0.3f}")
print(f"Test Accuracy: {lgb.score(X_test, y_test):0.3f}")
# Out:
# Training Accuracy: 0.948
# Test Accuracy: 0.943

# %%
pred_lgb = lgb.predict(test)
sub = pd.DataFrame({'ID':ss.ID,'Offset_fault':pred_lgb})
sub.to_csv('lgb.csv',index=False)

# %%
lgb = LGBMClassifier()
lgb.fit(X_train.values, y_train)
y_pred = lgb.predict(X_test)
print(f'Accuracy score on the X_test is: {accuracy_score(y_test, y_pred)}')
# Out:
# Accuracy score on the X_test is: 0.9427994616419919

# %%
# Feature importance
impo_df = pd.DataFrame({'feature': X.columns, 'importance': lgb.feature_importances_}).set_index('feature').sort_values(by = 'importance', ascending = False)
impo_df = impo_df[:12].sort_values(by = 'importance', ascending = True)
impo_df.plot(kind = 'barh', figsize = (10, 10), color = 'purple')
plt.legend(loc = 'center right')
plt.title('Bar chart showing feature importance', color = 'indigo', fontsize = 14)
plt.xlabel('Features', fontsize = 12, color = 'indigo')
plt.show()

# %%
test_df = test.drop(['Datetime_minute','Relative_Humidity'],axis=1)

# %%
X_train,X_test,y_train,y_test = train_test_split(X.drop(['Datetime_minute','Relative_Humidity'],axis=1), y, random_state=random_state, test_size=0.02)

# %%
lgb = LGBMClassifier()
lgb.fit(X_train.values, y_train)
y_pred = lgb.predict(X_test)
print(f'Accuracy score on the X_test is: {accuracy_score(y_test, y_pred)}')
# Out:
# Accuracy score on the X_test is: 0.9458277254374159

# %%
pred_lgb = lgb.predict(test_df)
sub = pd.DataFrame({'ID':ss.ID,'Offset_fault':pred_lgb})
sub.to_csv('lgb_with_FI.csv',index=False)

# %%
X.shape
# Out:
# (297177, 18)

# %%
X_train,X_test,y_train,y_test = train_test_split(X, y, test_size=0.05, random_state=786)




lgb = LGBMClassifier(objective= 'binary', 
            n_estimators= 20000,
            max_depth= 7,
            learning_rate=  0.01, 
            min_child_weight= 256,
            min_child_samples= 15, 
            reg_alpha= 10, 
            reg_lambda= 0.1, 
            subsample= 0.6, 
            subsample_freq= 1, 
            colsample_bytree= 0.4)
lgb.fit(X_train,y_train)

# %%
y_pred = lgb.predict(X_test)
print(f'Accuracy score on the X_test is: {accuracy_score(y_test, y_pred)}')

# %% [markdown]
# # trying other things

# %%
kjkjk
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [41], in <module>
# ----> 1 kjkjk
#
# NameError: name 'kjkjk' is not defined

# %%
for col in X.columns:
    X[col] = X[col].astype('category')

# %%
X.head()

# %%
y.value_counts()

# %%
X.dtypes

# %%
# %%time
kf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

preds = []
scores = []
feature_importance_df = pd.DataFrame()

for fold, (idx_train, idx_valid) in enumerate(kf.split(X, y)):
    X_train, y_train = X.iloc[idx_train], y.iloc[idx_train]
    X_valid, y_valid = X.iloc[idx_valid], y.iloc[idx_valid]
    
    model = LGBMClassifier()
    
    model.fit(X_train, y_train,
              eval_set = [(X_valid, y_valid)],
              verbose = False,
              early_stopping_rounds = 400)
    
    pred_valid = model.predict_proba(X_valid)[:,1]
    score = accuracy_score(y_valid, pred_valid)
    scores.append(score)
    
    fold_importance_df = pd.DataFrame()
    fold_importance_df["Feature"] = X.columns
    fold_importance_df["importance"] = model.feature_importances_
    fold_importance_df["fold"] = fold + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    
    print(f"Fold: {fold + 1} Score: {score}" "\n")
    print('||'*40, "\n")
    
    test_preds = model.predict_proba(X_test)[:,1]
    preds.append(test_preds)
    
print(f"Overall Validation Score: {np.mean(scores)}")

# %%
# from sklearn.model_selection import RandomizedSearchCV

# # Create a hyperparameter grid for RandomForestClassifier

# lgb_grid = {"n_estimators": np.arange(10, 1000, 50),
#            "max_depth": [None, 3, 5, 10],
#            "min_samples_split": np.arange(2, 20, 2),
#            "min_samples_leaf": np.arange(1, 20, 2)}

# %%
# # Setup random hyperparameter search for Lightbm
# rs_lgb = RandomizedSearchCV(LGBMClassifier(), 
#                            param_distributions=rf_grid,
#                            cv=5,
#                            n_iter=50,
#                            verbose=True)

# # Fit random hyperparameter search model for RandomForestClassifier()
# rs_lgb.fit(X_train, y_train)

# %%
# Find the best hyperparameters
# rs_lgb.best_params_

# %%
# # Evaluate the randomized search RandomForestClassifier model
# rs_lgb.score(X_test, y_test)

# %%
# model = LGBMClassifier(**rs_lgb.best_params_)
# model.fit(X_train,y_train)

# ypred = model.predict(test)

# sub = pd.DataFrame({'ID':ss.ID,'Offset_fault':ypred})
# sub.to_csv('model_lgb.csv',index=False)
